# %%
# The code was removed by DSX for sharing.
# Out:
#                                                 body  score  \
# 0  Now I have to say "Leroy can you please paint ...      1
# 1  Pizza doesn't scream when you put it in the ov...      0
# 2  ...and being there really helped me learn abou...      0
# 3  A Sunday school teacher is concerned that his ...      1
# 4  He got caught trying to sell the two books to ...      0
#
#                                                title  funny
# 0   I hate how you cant even say black paint anymore  False
# 1  What's the difference between a Jew in Nazi Ge...  False
# 2                     I recently went to America....  False
# 3  Brian raises his hand and says, “He’s in Heaven.”  False
# 4  You hear about the University book store worke...  False

# %%
# !pip install -U textblob nltk
# Out:
# Requirement already up-to-date: textblob in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement already up-to-date: nltk in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from nltk)

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /home/dsxuser/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /home/dsxuser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/dsxuser/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dsxuser/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /home/dsxuser/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /home/dsxuser/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
df_data_1['title']= df_data_1['title'].astype(str)

# %%
df_data_1['body']= df_data_1['body'].astype(str)

# %%
df_data_1['funny']= df_data_1['funny'].astype(str)

# %%
df_data_1['joke'] = df_data_1[['title', 'body']].apply(lambda x: ''.join(x), axis=1)

# %%
df_data_1
# Out:
#                                                      body  score  \
# 0       Now I have to say "Leroy can you please paint ...      1
# 1       Pizza doesn't scream when you put it in the ov...      0
# 2       ...and being there really helped me learn abou...      0
# 3       A Sunday school teacher is concerned that his ...      1
# 4       He got caught trying to sell the two books to ...      0
# 5                                Because the p is silent.      0
# 6       To avoid leaving tracks like a snail while wal...      0
# 7       Apparently "Whatever's low in cholesterol" was...      1
# 8                                       Character actors!      0
# 9                           You follow his fresh prints.       0
# 10      I always thought they were gunna hit me, not t...     15
# 11                                      ... Anal Destiny.      0
# 12                        Oh and it's also Valentines day      0
# ...

# %%
df_data_1['tuple_col'] = list(zip(df_data_1.joke, df_data_1.funny))

# %%
df_data_1
# Out:
#                                                      body  score  \
# 0       Now I have to say "Leroy can you please paint ...      1
# 1       Pizza doesn't scream when you put it in the ov...      0
# 2       ...and being there really helped me learn abou...      0
# 3       A Sunday school teacher is concerned that his ...      1
# 4       He got caught trying to sell the two books to ...      0
# 5                                Because the p is silent.      0
# 6       To avoid leaving tracks like a snail while wal...      0
# 7       Apparently "Whatever's low in cholesterol" was...      1
# 8                                       Character actors!      0
# 9                           You follow his fresh prints.       0
# 10      I always thought they were gunna hit me, not t...     15
# 11                                      ... Anal Destiny.      0
# 12                        Oh and it's also Valentines day      0
# ...

# %%
df_data_new = df_data_1['tuple_col']

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df_data_new, test_size=0.9)

# %%
train
# Out:
# 145450    (Chili JokeGuy walks into a restaurant, doesn'...
# 82624     (A little boy is trying to peel the lid off hi...
# 135133    (What did the one tampon say to the other tamp...
# 137377    (3 guys die and go to heaven...St. Peter was a...
# 50079     (Why frogs don't use Google?​They're angry sin...
# 42232     (Two scientists walk into a bar......the barma...
# 138059    (An old man was crying on a park benchAn old m...
# 39704     (Did you guys hear that Donald Trump met with ...
# 132684    (Why don't the circus lions eat the clowns?The...
# 116112    (Why can't Australians play chess?They keep sa...
# 130361        (What comes after March?April, fools!, False)
# 65310     (Accidentally sharing pornI have accidentally ...
# 150300    (french vs german , who won ?a drunk old man w...
# 174220    (A king and a Queen have a big problem......th...
# 177704    (A man was taking his blonde Jewish wife to a ...
# 113423    (StereotypesOK Google, How to deep fry yorkshi...
# ...

# %%
test
# Out:
# 190190    (why couldn't the rabbi eat out during passove...
# 176786    (What animal brings the most boys to the yard?...
# 165837    (Why don't old ladies receive orals sex?Have y...
# 72056     (I ate too much alphabet soup and became conso...
# 188186    (A man is out for an afternoon drive along a c...
# 14747     (Why is women’s soccer so rare?Why is women’s ...
# 21709             (Fart JokesAre sometimes shitty. , False)
# 154438    (What's the difference between Jewish people a...
# 86793     (Longest Joke Ever. (Worth reading)A corn flak...
# 85229     (Angelina Jolie JokeAngelina was sad.\nAngelin...
# 131178    (Honey, I just won the lottery!-- Honey, I jus...
# 139265    (I want my abs to be like NHS nurses...Cut, Fa...
# 13871     (Why are female golfers better than male golfe...
# 120889    (OH HELL!! ... Let's Offend Everybody!\nQ. Wha...
# 8823      (Why was the Black Knight downvoted?Because he...
# 26983     (Has anyone read Hitler's latest tweet?"Apprec...
# ...

# %%
train_list = list(train)

# %%
train_list
# Out:
# [('Chili JokeGuy walks into a restaurant, doesn\'t know what he wants. At the next table is a guy with a plate of food and a bowl of chili, that looks good he thinks. When the waiter comes by, he says\n" I\'d like a bowl of chili, and a burger, please" Waiter says, "sorry , that was last bowl of chili."  " Ok just bring the burger" After awhile he notices the guy next to him seems to be done, and the bowl of chili is still there, full. " hey, buddy, you gonna eat that?" \n" No" \n"Mind if I do?"\n"Go ahead"\nSo he\'s eating the chili, and at the bottom of the bowl finds a dead mouse, and pukes it all back up.\nOther guy says...\n" That\'s as far as I got too." ',
#   'False'),
#  ('A little boy is trying to peel the lid off his tub of yoghurt..He gets frustrated and yells "fuckin\' lid!".\n\nHis mother turns to his father and says "where do you think he got that from?" \n\nThe father says "the fuckin\' fridge you dumb cunt".',
#   'True'),
# ...

# %%
test_list = list(test)

# %%
from textblob.classifiers import NaiveBayesClassifier

# %%
classify = NaiveBayesClassifier(train_list)
